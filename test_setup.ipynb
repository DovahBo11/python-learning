# %% [markdown]
# Guide for commiting changes made in VScode to attached repository; go to "Source control" panel on the left (ctrl+shift+G), will give a list of changes to files, press the "+" to "Stage changes" your changes to the "Staged changes" list, then press the "commit" btn. Some pop ups may come up, select the pop up option that seems correct and then your changes will apply to the repository. However if working with more people your commit request must be reviewed by manager or administrator.

# %%
print("testing 2")
# Out:
# testing 2
